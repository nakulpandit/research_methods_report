# %%
# !jupyter nbconvert --to html /workspaces/research_methods_report/rm.ipynb
# Out:
# [NbConvertApp] Converting notebook /workspaces/research_methods_report/rm.ipynb to html
# [NbConvertApp] WARNING | Alternative text is missing on 4 image(s).
# [NbConvertApp] Writing 520918 bytes to /workspaces/research_methods_report/rm.html
